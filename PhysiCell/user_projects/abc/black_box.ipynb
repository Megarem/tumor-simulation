# %% [markdown]
# # Cell motility study
#
# In this notebook we will go through how we can use PhysiCOOL to test the effect of the cell motility parameters on the cells' trajectories and migration patterns. We will start by creating a simple black box model to run the simulation through Python and then adding other components to extend its functionalities.

# %% [markdown]
# ## Creating the initial cell positions .csv file
#
# We want to study the effect of migration parameters (namely the **speed** and **migration_bias**). Our PhysiCell model considers cells that are attracted to oxygen and there is an oxygen gradient from `y_max` to `y_min`. Thus, we will place the cells close to the `y_min` wall to then evaluate how much they migrated towards the opposite wall.

# %%
import numpy as np

# Creates an array with the cell coordinates and saves it to a csv file.
# Cells will be placed in a line (y=-450), in the same z-plane (z=0).
cell_definition = 0
z_plane = 0
y_coordinate = -450
x_min = -450
x_max = 450
x_spacing = 100

coords = np.asarray([[x, y_coordinate, z_plane, cell_definition] 
                     for x in np.arange(x_min, x_max+1, x_spacing)])
                     
np.savetxt("config/cells.csv", coords, delimiter=",")

# %% [markdown]
# ## Setting up the environment
#
# We can use PhysiCOOL to compile our project with a Python command and create a black box that can be used to run the PhysiCell model (we must be in the same directory as the simulation files).

# %%
# %pip install physicool
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: physicool in /home/aymeric/.local/lib/python3.10/site-packages (0.2.4)
# Requirement already satisfied: matplotlib<4.0.0,>=3.5.1 in /home/aymeric/.local/lib/python3.10/site-packages (from physicool) (3.8.4)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in /home/aymeric/.local/lib/python3.10/site-packages (from physicool) (1.23.0)
# Requirement already satisfied: pandas<2.0.0,>=1.4.1 in /home/aymeric/.local/lib/python3.10/site-packages (from physicool) (1.5.3)
# Requirement already satisfied: pydantic<2.0.0,>=1.9.1 in /home/aymeric/.local/lib/python3.10/site-packages (from physicool) (1.10.15)
# Requirement already satisfied: scipy<2.0.0,>=1.8.0 in /home/aymeric/.local/lib/python3.10/site-packages (from physicool) (1.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/aymeric/.local/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.5.1->physicool) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/aymeric/.local/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.5.1->physicool) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/aymeric/.local/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.5.1->physicool) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/aymeric/.local/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.5.1->physicool) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/aymeric/.local/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.5.1->physicool) (24.0)
# Requirement already satisfied: pillow>=8 in /home/aymeric/.local/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.5.1->physicool) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib<4.0.0,>=3.5.1->physicool) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/aymeric/.local/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.5.1->physicool) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/aymeric/.local/lib/python3.10/site-packages (from pandas<2.0.0,>=1.4.1->physicool) (2024.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/aymeric/.local/lib/python3.10/site-packages (from pydantic<2.0.0,>=1.9.1->physicool) (4.11.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from cycler>=0.10->matplotlib<4.0.0,>=3.5.1->physicool) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from physicool import optimization as opt

# Compiles the project and creates a black box object for it
opt.compile_project()    
black_box = opt.PhysiCellBlackBox()

# %% [markdown]
# ## Running the model
#
# Running a model with the black box is quite easy: we just have to call the `run()` method. Furthermore, we can choose the number of replicates to be run and whether the output data should be saved (it will be stored in a new folder called `temp`).

# %%
opt.clean_tmp_files()
black_box.run(number_of_replicates=1, keep_files=True)

# %% [markdown]
# ## Plotting the results
#
# PhysiCOOL offers functions to extract and plot the cell trajectories both in 3D and 2D.

# %%
# %matplotlib inline
from physicool.processing import get_cell_trajectories
from physicool.plotting import plot_trajectories_3d, plot_trajectories_2d

trajectories = get_cell_trajectories("temp", version="1.9.1")
plot_trajectories_3d(trajectories)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       2 from physicool.processing import get_cell_trajectories
#       3 from physicool.plotting import plot_trajectories_3d, plot_trajectories_2d
# ----> 5 trajectories = get_cell_trajectories("temp", version="1.9.1")
#       6 plot_trajectories_3d(trajectories)
#
# File ~/.local/lib/python3.10/site-packages/physicool/processing.py:278, in get_cell_trajectories(output_path, version)
#     275     cells["timestep"] = i
#     276     data.append(cells)
# --> 278 new_data = pd.concat(data)
#     279 trajectories = [
#     280     new_data[new_data["ID"] == cell_id][["position_x", "position_y", "position_z"]]
#     281     for cell_id in new_data["ID"].unique()
#     282 ]
#     284 return trajectories
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/concat.py:425, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     422     objs = list(objs)
#     424 if len(objs) == 0:
# --> 425     raise ValueError("No objects to concatenate")
#     427 if keys is None:
#     428     objs = list(com.not_none(*objs))
#
# ValueError: No objects to concatenate

# %% [markdown]
# ## Adding a params updater to the black box
#
# We can add a `ParamsUpdater` instance to our black box to update the XML file with new parameter values before the simulation is run.

# %%
from physicool.updaters import CellUpdater, update_motility_values

# Define the updater we want to use (change motility data)
new_values = {"speed": 5.0, "migration_bias": 1.0}
updater = CellUpdater(updater_function=update_motility_values,
                     config_path="config/PhysiCell_settings.xml", cell_definition_name="default")

# Assign the updater to the black box
black_box.updater = updater

# Run the model with the new values
opt.clean_tmp_files()
black_box.run(params=new_values)

# %%
# Plot the trajectories
trajectories = get_cell_trajectories("temp", version="1.9.1")
plot_trajectories_3d(trajectories)
# Out:
# <Axes3D: >

# %% [markdown]
# ## Adding a processing routine to extract the final positions
#
# We can also add a `OutputProcessor` instance to extract and quantify data from our output files. In this case, we are interested in getting the y coordinates for the last time point, to assess how close the cells are at the end of the simulation to the `y_max` wall (oxygen source).

# %%
from physicool.processing import get_final_y_position

opt.clean_tmp_files()
black_box.processor = get_final_y_position
black_box.version = "1.9.1"
final_positions = black_box.run(new_values)

print("\n\n Cell final positions:")
print(final_positions)
# Out:
#  Cell final positions:
# [ 493.46842872  493.46842872 -106.75        492.2361941   492.29328404
#   493.31196176 -106.75        492.2361941   492.29328404  492.29328404]
